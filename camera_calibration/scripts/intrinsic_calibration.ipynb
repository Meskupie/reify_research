# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [16, 12]

def drawImage(img):
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.show()

# %%
import os
import cv2
import numpy as np
from calibration import IntrinsicCalibrator

cameraName = 'poc_1'

basePath = os.path.abspath('')
calibrationDataPath = os.path.join(basePath,'../calibration_data')
sampleDataPath = os.path.join(basePath,'../sample_data')
paramPath = os.path.join(calibrationDataPath,cameraName,'intrinsics.yaml')
imagePath = os.path.join(calibrationDataPath,cameraName,'images')

calibrator = IntrinsicCalibrator()
calibrator.calibrate_from_image_dir(paramPath,imagePath)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-c4891c5c5d18> in <module>
#       2 import cv2
#       3 import numpy as np
# ----> 4 from calibration import IntrinsicCalibrator
#       5
#       6 cameraName = 'poc_1'
#
# ModuleNotFoundError: No module named 'calibration'

# %%
img = cv2.imread(os.path.join(sampleDataPath,'intrinsic_test.png'))
out = calibrator.undistort_image(img)
drawImage(img)
drawImage(out)

# %%
paramPath = os.path.join(calibrationDataPath,cameraName,'intrinsics.yaml')
videoInPath =  os.path.join(sampleDataPath,'intrinsic_test.mp4')
videoOutPath = os.path.join(calibrationDataPath,cameraName,'sample_test.avi')

calibrator.undistort_video(videoInPath,videoOutPath)
# Out:
# 100%|██████████| 5773/5773 [01:17<00:00, 74.58it/s]
