# %%
# %load_ext autoreload
# %autoreload 2

import cv2
import numpy as np
import sys

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [16, 12]

from calibration import *

RESOLUTION = (1440,1920,3)

def captureImage(fname):
    img = cv2.imread(fname)
    if img.shape[:2] != RESOLUTION[:2][::-1]:
        img = cv2.resize(img,RESOLUTION[:2][::-1])
    return img

def drawImage(img):
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.show()

# %%
ic = IntrinsicCalibrator()

basepath = os.path.abspath('')
param_path = os.path.join(basepath,'test.yaml')
image_path = os.path.join(basepath,'checker_imgs')

ic.calibrate_from_image_dir(param_path,image_path)
# Out:
# resolution (1440, 1920, 3)

# %%
img = captureImage(os.path.join(image_path,'checker_4.jpg'))

out = ic.apply_intrinsic_transform(img)
drawImage(img)
drawImage(out)
# Out:
# (1440, 1920, 3)
# (1440, 1920, 3)
# (1440, 1920, 3)

# %%
out = intrinsic_calibratior.applyIntrinsicTransform(img)

# %%
import random
corners = random.sample(population=filteredCorners, k=50)

resolution = (1280,720,3)
basepath = os.path.abspath('')
param_path = os.path.join(basepath,'test.yaml')

intrinsicCalibrator = IntrinsicCalibrator()
intrinsicCalibrator.params_from_corners_list(param_path,corners,resolution)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-154-2b09f90a430a> in <module>
#       7
#       8 intrinsicCalibrator = IntrinsicCalibrator()
# ----> 9 intrinsicCalibrator.params_from_corners_list(param_path,corners,resolution)
#
# ~/Documents/Reify/reify_research/camera_calibration/Code/calibration.py in params_from_corners_list(self, paramPath, imageKeypoints, resolution)
#      95         # 4th arg is the free scaleing param, 0 means scale in, 1 means scale out
#      96         newcameramtx, fov = cv2.getOptimalNewCameraMatrix(mtx,dist,self.resolution[:2][::-1],0)
# ---> 97         calibrationError = self.calculate_error(imageKeypoints,objectKeypoints,mtx,dist,rvecs,tvecs)
#      98         self.save_camera_params(paramPath,mtx,newcameramtx,dist,fov,calibrationError)
#      99         self.load_camera_params(paramPath)
#
# ...
